# %% [markdown]
# # multi calculus
# ## vector
# ### dot product
#
# ### cross product
#
# ## parameter equation
# ### velocity
# $$ \vec{v} = d\vec{r}/dt = \hat{T}ds/dt $$
# $$ speed = |\vec{v}| $$
# veloctiy is tangent of the curve
#
# ### acceleration
# $$ \vec{a} = d\vec{v}/dt $$
#
# ## crtical point
# 当 $\nabla f = 0$ 的时候，获得极值点。通过二阶偏导，确认是 local min/local max/saddle
# - local min
# - local max
# - saddle
#
# ## linear approximation
# $$ \Delta f \approx \partial f/\partial x * \Delta x + \partial f/\partial y * \Delta y $$
#
# ## least squares
#
# ## partial differential
#
# ## total differential
# $$ df = \partial f / \partial x * dx + \partial f / \partial y * dy $$
# if $x=x(t)$ and $y=y(t)$
# $$ df/dt = \partial f / \partial x * \partial x / \partial t + \partial f / \partial y * \partial y / \partial t $$
#
# ## level curve & level surface
# f(x,y) 描绘的是level curve  f(x,y,z) 描绘的是level surface
# if $f(x,y) = c $
# $$ normal = \hat{n} = \frac{\nabla f}{|\nabla f|} $$
#
# ## 梯度
# 梯度垂直于level surface, 也就是level sruface的法向量
# $$ \nabla f = <\partial f/ \partial x, \partial f / \partial y> $$
#
# ## 方向导数
# $$ \frac{df}{ds|_{u}} = \nabla f \cdot \hat{u} $$
#
#
# ## 非独立变量
# f(x,y,z) where g(x,y,z)
# - 格朗日乘数找出可能的极值点
# - 多元函数+约束方程 找出偏微分(隐函数微分)
#
# ## constrained partial derivative(约束偏导)
# 给定 $g(x,y,z) = c$ 时，$\partial f / \partial x$有什么意义？
#
# ## 重积分
# 在极坐标系中有时候会更简单
# - 通过调换积分顺序可以简化积分计算
# - 通过变量替换也可以简化积分计算（简化函数表达式，简化积分区(积分区域可能需要分块，变量替换后可以不分块))
# - 通过变量替换也可以把单变量很难积分的函数转化成多变量函数进行积分例如$\int e^{-x^{2}} dx$
# - 求平面面积
# - 求连续函数的平均值，也可以做加权平均值
#
# ## 坐标系转换
# jacobian矩阵:
# $$ dudv = |\frac{\partial (u, v)}{\partial (x, y)}| dxdy $$
#
#
# ## moment of inertia
#
# ## 线积分
# ### 定义
# if $\vec{F} = <M, N>$
# $$ \int \vec{F} \cdot d\vec{r} = \int Mdx + Ndy $$
#
# ### 梯度场线积分证明链接
# - [第一种](http://onlinelibrary.wiley.com/higheredbcs//legacy/college/hugheshallett/0471484822/theory/hh_focusontheory_sectionl.pdf)
# - [第二种](http://tutorial.math.lamar.edu/Classes/CalcIII/FundThmLineIntegrals.aspx)
#
# ### 性质
# - 路径独立
# - 保守场(Conservative Vector Fields) => 曲线闭合的线积分是0
# - 特殊的例子 F=<-y, x>
# - exact differential 恰当微分
#
# ### 确定向量场是否是一个梯度场
# $\vec{F}$ defined in a simple-connect region(单连通区域）and
# $$ curl \vec{F} = 0  $$
# then:
#    $$ \nabla f = \vec{F} $$
#
# ### 梯度场求积原函数
# - 通过简单路径求出原函数
# - 通过偏导求积分
#
# 计算量相同
#
# ## Curl(旋度)
# $$ curl\vec{F} = \nabla  $$
#
# ## 格林公式
#
#
# ## Flux(通量)
# ### 线通量
# $$ \int \vec{F}*\hat{n} dS $$
#
# ### 面通量
# $$ \iint \vec{F}*\hat{n} dS $$
#
# ### 高斯定理
# 空心闭合曲线/曲面同样适合 => 对不方便求通量的几何，可以通过外层包裹一个简单方面计算通量的几何，通过高斯定理间接求出
#
#
# ## divegence(散度 )
# delta*F
#
# ### diffusion equation(扩散方程)
#
# ## 单连通
#
#
# ## 面积分
# $$dS = a^2sin\phi d\phi d\theta$$
#
# ## 斯托克斯
#
# ## 拓扑
#
# ## 不可定向曲面
#
# - $\oint$

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(10, 9), dpi= 96)
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
